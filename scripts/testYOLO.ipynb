# %%
from ultralytics import YOLO

# %%
model = YOLO('D:\\dis\\model\\yolov8n.pt')

results = model.train(data='D:\\dis\\datasets\\fish-v9\\fishes\\data.yaml', epochs=1, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.2.21 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.37 🚀 Python-3.10.11 torch-2.2.2+cpu CPU (12th Gen Intel Core(TM) i5-12450H)
# ...
